# %% [markdown]
# # Savegame Analysis Workbench Minimal
#
# Build or refresh the raw savegame parquet dataset first:
#
# ```bash
# uv run ppc savegame-notebooks build
# ```
#
# This compact run-all notebook uses the same selectors as the full workbench and skips the heavy map widgets.

# %%
# %matplotlib inline

import importlib
from prosper_or_perish_constructor import savegame_notebook as nb
nb = importlib.reload(nb)

data = nb.open_data(load_map_assets=False)
workbench = data.workbench(
    good_search="victuals",
    market_search=None,
    building_search="cookery",
    country_search="england",
    top_n=12,
)
nb.show_selection(workbench)

# %% [markdown]
# ## Runtime Cadence

# %%
runtime = nb.show_runtime_cadence(data, workbench)
runtime.df

# %% [markdown]
# ## Global Distributions

# %%
location_ranks = nb.show_location_rank_distribution(data, workbench)
location_ranks.frame.tail(12)

# %%
pop_types = nb.show_pop_type_distribution(data, workbench)
pop_types.frame.tail(12)

# %% [markdown]
# ## Goods Pressure

# %%
goods_pressure = nb.show_goods_pressure(
    data,
    workbench,
    selected_good="victuals",
    rank_mode="shortage",
    top_n=12,
)
selected_good_global = goods_pressure.selected_good_global
selected_good_global.tail(12)

# %% [markdown]
# ## Food Price Volatility

# %%
food_prices = nb.show_food_price_volatility(data, workbench, top_n=12)
food_prices.top_erratic

# %% [markdown]
# ## Buildings

# %%
buildings = nb.show_global_buildings(data, workbench)
buildings.time_series.tail(12)

# %%
slot_index = 2
nb.show_building_slot(workbench, buildings, slot=slot_index)
